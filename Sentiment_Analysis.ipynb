# %% [markdown]
# <a href="https://colab.research.google.com/github/spidervamsi/MedicalTweetsAnalysis/blob/master/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip install fasttext
# Out:
# ...
#      |████████████████████████████████| 61kB 1.1MB/s
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.1-cp36-cp36m-linux_x86_64.whl size=2387161 sha256=1f41c09f2d961961addd2ab3bb85b82bcc9413ae3b14b3798e4576c48cddf4f5
#   Stored in directory: /root/.cache/pip/wheels/9f/f0/04/caa82c912aee89ce76358ff954f3f0729b7577c8ff23a292e3
# Successfully built fasttext
# ...

# %%
# !pip install emoji
# Out:
# ...
#      |████████████████████████████████| 51kB 943kB/s
# ...
#   Created wheel for emoji: filename=emoji-0.5.4-cp36-none-any.whl size=42176 sha256=34bbc169704db8215b510e8c0812c562d1b6c1216d2879d2325d6464f496cae7
#   Stored in directory: /root/.cache/pip/wheels/2a/a9/0a/4f8e8cce8074232aba240caca3fade315bb49fac68808d1a9c
# Successfully built emoji
# ...

# %%
import pandas as pd
import numpy as np
import fasttext
import re
import sys
import os
import nltk
nltk.download('punkt')
import csv
import datetime
from bs4 import BeautifulSoup
import itertools
import emoji
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
usecols = (2,4)
dataframe = pd.read_table("/content/task1_training.tsv",usecols=usecols)
dataframe
# Out:
#                                                    tweet  class
# 0      These new anti-anxiety meds make me so sleepy😴...      1
# 1      @xmermaidmama you can try vitamins for Olivia!...      1
# 2      Toby set up the humidifier for me in the room ...      1
# 3      I'm an 8. They also just started me on pitocin...      1
# 4      @sstuckeyy I didn't take prenatals at all, peo...      1
# ...                                                  ...    ...
# 55414  Some people are too focused on money that they...      0
# 55415   I really don't be caring about people's opinions      0
# 55416  󾁀 Babymoonin'󾬓󾬘 #bumpinbesties #33weeks #36wee...      0
# 55417                       @GreatNorthMum Thank you. Xx      0
# 55418  @_hicaroline I don't get why Comcast isn't dow...      0
#
# [55419 rows x 2 columns]

# %%
import re
import string
from bs4 import BeautifulSoup

#for tweet in tweet_data:
def preprocess_tweet(tweet):
    # Clean the training data
    # print(tweet)
    
    #Escaping HTML characters
    tweet = BeautifulSoup(tweet).get_text()
    
    #lowercase
    tweet = tweet.lower()
    
    #remove links
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+)|(http?://[^\s]+))','',tweet)
    
    #Remove usernames
    tweet = re.sub('@[^\s]+','', tweet)
    
    # replace hashtags by just words
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
    
    #Removal of Punctuation
    tweet = ' '.join(re.sub("[\.\,\!\?\:\;\-\=]", " ", tweet).split())
    
    #correct all multiple white spaces to a single white space
    tweet = re.sub('[\s]+', ' ', tweet)
   
    #remove space at the beginning and the end
    tweet = tweet.strip()
    # print(tweet)
    
    return tweet 
    
        
#     # remove special characters, numbers, punctuations
#     text = text.replace("[^a-zA-Z#]", " ")
#     # Additional clean up : removing words less than 3 chars, and remove space at the beginning and the end
#     text = re.sub(r'\W*\b\w{1,3}\b', '', text)

# %%
train_data =""
with open('SE_train.txt', 'w') as txtoutfile:
        for data in dataframe.iterrows():
            txtoutfile.write('__label__'+str(data[1][1])+"\t"+ preprocess_tweet(data[1][0])+'\n' )
            train_data=train_data+'__label__'+str(data[1][1])+"\t"+ preprocess_tweet(data[1][0])+'\n'
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 69
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:336: UserWarning: "https://t.co/oewqnWJA4k" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:336: UserWarning: "https://t.co/29HB3YRChW" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# ...

# %%
usecols = (2,4)
dataframe = pd.read_table("/content/task1_validation.tsv",usecols=usecols)
dataframe
# Out:
#                                                    tweet  class
# 0      Cayden's already starting to open his eyes! Th...      0
# 1                        Its a Johnny cash kinda mornin'      0
# 2                                            In my chest      0
# 3                   sumn slight 💋 http://t.co/QZlmWGmuOp      0
# 4      🙌🏻never have I ever been excited to see Adelan...      0
# ...                                                  ...    ...
# 13848                         @Jaylahtiara 🙄 here you go      0
# 13849  That Jamie foxx movie was coo, I just don't se...      0
# 13850  i will ALWAYS protect my son, &amp; ill be dam...      0
# 13851  Babies been kicking strong the past few days &...      0
# 13852  Sharing a great blog post this Sunday: How I B...      0
#
# [13853 rows x 2 columns]

# %%
eval_data=""
with open('SE_validation.txt', 'w') as txtoutfile:
        for data in dataframe.iterrows():
            txtoutfile.write('__label__'+str(data[1][1])+"\t"+ preprocess_tweet(data[1][0])+'\n' )
            eval_data=eval_data+'__label__'+str(data[1][1])+"\t"+ preprocess_tweet(data[1][0])+'\n'
# Out:
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:336: UserWarning: "http://t.co/WJMMsU6ixl" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:336: UserWarning: "https://t.co/x4nWvT6pCg" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:336: UserWarning: "http://t.co/lzZH0S5pES" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
# ...

# %%
def train(training_data_path,validation_data_path):
    print('Training start')
    hyper_params = {"lr": 0.01,
                    "epoch": 2,
                    "wordNgrams": 20,
                    "dim": 20}     
                            
    # Train the model.
    model = fasttext.train_supervised(input=training_data_path, **hyper_params)
    print("Model trained with the hyperparameter \n {}".format(hyper_params))

    model_acc_validation_set = model.test(validation_data_path)
    
    # DISPLAY ACCURACY OF TRAINED MODEL
    text_line =  "validation:" + str(model_acc_validation_set[1]) + '\n'
    print(text_line)

# %%
training_data_path = os.path.join("SE_train.txt")
validation_data_path = os.path.join("SE_validation.txt")

# %%
train("/content/SE_train.txt","/content/SE_validation.txt")
# Out:
# Training start
# Model trained with the hyperparameter
#  {'lr': 0.01, 'epoch': 20, 'wordNgrams': 2, 'dim': 20}
# validation:0.9974734714502274
