# %% [markdown]
# <a href="https://colab.research.google.com/github/spidervamsi/MedicalTweetsAnalysis/blob/master/Copy_of_NER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import re

# %%
import re
import string
from bs4 import BeautifulSoup

#for tweet in tweet_data:
def preprocess_tweet(tweet):
    # Clean the training data
    # print(tweet)
    
    #Escaping HTML characters
    tweet = BeautifulSoup(tweet).get_text()
    
    #lowercase
    tweet = tweet.lower()
    
    #remove links
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+)|(http?://[^\s]+))','',tweet)
    
    #Remove usernames
    tweet = re.sub('@[^\s]+','', tweet)
    
    # replace hashtags by just words
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
    
    #Removal of Punctuation
    tweet = ' '.join(re.sub("[\.\,\!\?\:\;\-\=]", " ", tweet).split())
    
    #correct all multiple white spaces to a single white space
    tweet = re.sub('[\s]+', ' ', tweet)
   
    #remove space at the beginning and the end
    tweet = tweet.strip()
    # print(tweet)
    
    return tweet 
    
        
#     # remove special characters, numbers, punctuations
#     text = text.replace("[^a-zA-Z#]", " ")
#     # Additional clean up : removing words less than 3 chars, and remove space at the beginning and the end
#     text = re.sub(r'\W*\b\w{1,3}\b', '', text)

# %%
usecols = (4,5,6)
dataframe = pd.read_table("/content/task3_training.tsv",usecols=usecols)
dataframe
# Out:
#                extraction  ...                                              tweet
# 0                     NaN  ...  @seefisch:oral drugs for pyelonephritis:ciprof...
# 1                     NaN  ...  happy for wellbutrin; has similar effects as a...
# 2                     NaN  ...  @stilgarg i'm ok ty have an official diagnosis...
# 3                     NaN  ...      i'm soo depressed cymbalta couldn't help me .
# 4                     NaN  ...  time for my daily afternoon relaxation ritual ...
# ...                   ...  ...                                                ...
# 2241                  NaN  ...  i will admit that most people would agree zypr...
# 2242  gain so much weight  ...  that zyprexa really makes your vocal chords ma...
# 2243                  NaN  ...  @incubator04 i'm hoping that i get on the zypr...
# 2244   increase my weight  ...  i'm so fine today. increasing zyprexa,my condi...
# 2245        gained 30 lbs  ...  i might have gained 30 lbs in 6 weeks on zypre...
#
# [2246 rows x 3 columns]

# %%
train_data=[]
for tweet in dataframe.iterrows():
  tweet_txt = tweet[1][2].lower()
  tweet_txt = preprocess_tweet(tweet_txt)
  data = []
  entities = []

  if not pd.isnull(tweet[1][1]):
    drug = preprocess_tweet(tweet[1][1])
    start = len(tweet_txt)+1
    
    tweet_txt = tweet_txt + " "+ drug
    end = len(tweet_txt)
    entities.append((start, end, "DRG"))

  data.append(tweet_txt)

  if not pd.isnull(tweet[1][0]):
    extra_txt_s =   preprocess_tweet(tweet[1][0])
    start=tweet_txt.find(extra_txt_s)
    end = start+len(extra_txt_s)
    extra_txt_s = extra_txt_s.split()
    entities.append((start, end, "ADR"))
  
  adr_data = {"entities": entities}
  data.append(adr_data)
  train_data.append(tuple(data))

  # break

# %%
train_data
# Out:
# [('drugs for pyelonephritis ciprofloxacin levofloxacin tmp/smz do not use nitrofurantoin for pyelo(only cystitis) ofloxacin',
#   {'entities': [(111, 120, 'DRG')]}),
#  ('happy for wellbutrin has similar effects as adderall trazodone is super promising for sleep but abilify can cause weight gain _ trazodone',
#   {'entities': [(128, 137, 'DRG')]}),
#  ("i'm ok ty have an official diagnosis of bipolar now feeling ok at the moment lamotrigine has been increased having monotherapy / lamotrigine",
#   {'entities': [(129, 140, 'DRG')]}),
#  ("i'm soo depressed cymbalta couldn't help me cymbalta",
#   {'entities': [(44, 52, 'DRG')]}),
#  ('time for my daily afternoon relaxation ritual of smoking weed taking 2 mgs of clonazepam and 400 mg of seroquel xr seroquel',
#   {'entities': [(115, 123, 'DRG')]}),
#  ("questionable x ray result nothing a little levaquin won't help oh yeah and the cough meds with codeine levaquin",
#   {'entities': [(103, 111, 'DRG')]}),
#  ('does nicotine gum actually help with quitting smoking nicotine',
#   {'entities': [(54, 62, 'DRG')]}),
#  ('third night of diarrhea and first dose of norfloxacin gosh gonna die of dehydration norfloxacin',
#   {'entities': [(84, 95, 'DRG')]}),
#  ('prescribed wellbutrin and got an okay to get off effexor as fast as possible to be on the look out for symptoms of mania in case bipolar effexor',
#   {'entities': [(137, 144, 'DRG')]}),
#  ('nicotine is so stress relieving nicotine', {'entities': [(32, 40, 'DRG')]}),
#  ('104 ) this is a pic of me during my depression spikey dread curls heavy metal prozac bass guitar prozac',
#   {'entities': [(97, 103, 'DRG')]}),
#  ("gotta thank the lord for the weed and the nicotine i can't sleep close my eyes and see wicked things nicotine",
#   {'entities': [(101, 109, 'DRG')]}),
#  ("if you can't sleep in a high stress job the latest best thing under the care of a qualified physician is low dose quetiapine (seroquel) seroquel",
#   {'entities': [(136, 144, 'DRG')]}),
#  ('fibro question who has been on the drug merry go round (vicodin to lyrica to elavil to lunesta to cymbalta to lexipro on and on ) cymbalta',
#   {'entities': [(130, 138, 'DRG')]}),
#  ('oh yay ciprofloxacin just in time for the weekend i thank you vietnam & egypt alcohol see you in 7 days sick ofloxacin',
#   {'entities': [(109, 118, 'DRG')]}),
#  ('i stopped taking my trazodone so bring on another sleepless night trazodone',
#   {'entities': [(66, 75, 'DRG')]}),
#  ('hopefully benadryl is on my side tonight and i can get some sleep got a lozenge and dayquil and water on standby lozenge',
#   {'entities': [(113, 120, 'DRG')]}),
#  ("it sucks being bipolar i am taking geodon it seems to work most of the time i'm new to this was ptsd now bipolar too geodon",
#   {'entities': [(117, 123, 'DRG')]}),
#  ("i exited out of my brother's bloons game and now he has fallen into a deep pit of depression i hope mom doesn't make me pay for his prozac prozac",
#   {'entities': [(139, 145, 'DRG')]}),
#  ("seroquel an anti psychotic usually for schiz people but i'm on a small dose seroquel",
#   {'entities': [(76, 84, 'DRG')]}),
#  ('that is scary if you do get it the antibiotic cipro will cure it keepingfingerscrossed cipro',
#   {'entities': [(87, 92, 'DRG')]}),
#  ("how's your crohn's i'm back on remicade and pentasa after failing at humira and cimzia humira",
#   {'entities': [(87, 93, 'DRG')]}),
#  ('dis lady has the worst cough i wish i had a lozenge lozenge',
#   {'entities': [(52, 59, 'DRG')]}),
#  ('thank god for vyvanse or i would be sleepping on the cash register right now vyvanse',
#   {'entities': [(77, 84, 'DRG')]}),
#  ('ha try not to do that water sleep cipro and the occasional xanax can cure all travel related illnesses beprepared cipro',
#   {'entities': [(114, 119, 'DRG')]}),
#  ('prescription i have zoplicone nice and gentle but work i have zometa to keep the bones strong and control the tumours zometa',
#   {'entities': [(118, 124, 'DRG')]}),
#  ('iti needs to quit hiring teachers that have already retired from one job to take this one imma overdose on vyvanse trying to stay awake vyvanse',
#   {'entities': [(136, 143, 'DRG')]}),
#  ('cymbalta withdrawal has reached a peak lost vision and almost crashed my car from a brain zap thanks a zillion elililly bigpharma cymbalta',
#   {'entities': [(130, 138, 'DRG'), (39, 50, 'ADR')]}),
#  ('cymbalta withdrawal has reached a peak lost vision and almost crashed my car from a brain zap thanks a zillion elililly bigpharma cymbalta',
#   {'entities': [(130, 138, 'DRG'), (9, 19, 'ADR')]}),
#  ('i hate cipro antibiotic nauseous cf hospitallife cysticfibrosis cipro',
#   {'entities': [(64, 69, 'DRG'), (24, 32, 'ADR')]}),
#  ("reppin zoloft&seroquel since last november i'm hella gainin weight too awesome i'm fat and can't cum i own seroquel",
#   {'entities': [(107, 115, 'DRG'), (91, 100, 'ADR')]}),
#  ("reppin zoloft&seroquel since last november i'm hella gainin weight too awesome i'm fat and can't cum i own seroquel",
#   {'entities': [(107, 115, 'DRG'), (83, 86, 'ADR')]}),
#  ("reppin zoloft&seroquel since last november i'm hella gainin weight too awesome i'm fat and can't cum i own seroquel",
#   {'entities': [(107, 115, 'DRG'), (53, 66, 'ADR')]}),
#  ("i've had a trazodone headache all day i heard they go away within a week hopeso iactuallyslept trazodone",
#   {'entities': [(95, 104, 'DRG'), (21, 29, 'ADR')]}),
#  ("i've had ocd symptoms like that for a while but seems like the seroquel exacerbates things and now this \\ seroquel",
#   {'entities': [(106, 114, 'DRG'), (72, 83, 'ADR')]}),
#  ('and that ladies and gentlemen is that fuzzy noisy head sleep quetiapine quetiapine',
#   {'entities': [(72, 82, 'DRG')]}),
#  ("i finally had an appetite made food gone humira why won't you let me eat humira",
#   {'entities': [(73, 79, 'DRG'), (52, 72, 'ADR')]}),
#  ("i don't care if they are toxic haha putting the cipro drops in is essentially equivalent to torture oww cipro",
#   {'entities': [(104, 109, 'DRG'), (100, 103, 'ADR')]}),
#  ("i don't care if they are toxic haha putting the cipro drops in is essentially equivalent to torture oww cipro",
#   {'entities': [(104, 109, 'DRG'), (25, 30, 'ADR')]}),
#  ("i don't care if they are toxic haha putting the cipro drops in is essentially equivalent to torture oww cipro",
#   {'entities': [(104, 109, 'DRG'), (78, 99, 'ADR')]}),
#  ('dizzy out if it and confused on the drugs upping the baclofen slowly now as i seem better on these baclofen',
#   {'entities': [(99, 107, 'DRG'), (20, 28, 'ADR')]}),
#  ('dizzy out if it and confused on the drugs upping the baclofen slowly now as i seem better on these baclofen',
#   {'entities': [(99, 107, 'DRG'), (0, 5, 'ADR')]}),
#  ('dizzy out if it and confused on the drugs upping the baclofen slowly now as i seem better on these baclofen',
#   {'entities': [(99, 107, 'DRG'), (6, 15, 'ADR')]}),
#  ('cause humira gives me a lot of rashes and like most of these drugs skin sensitivity happens humira',
#   {'entities': [(92, 98, 'DRG'), (67, 83, 'ADR')]}),
#  ('cause humira gives me a lot of rashes and like most of these drugs skin sensitivity happens humira',
#   {'entities': [(92, 98, 'DRG'), (31, 37, 'ADR')]}),
#  ("*buts in* you don't wanna miss venlafaxine no no it made me so wonky missing one day ouch venlafaxine",
#   {'entities': [(90, 101, 'DRG'), (63, 68, 'ADR')]}),
#  ('my vyvanse makes me nocturnal vyvanse',
#   {'entities': [(30, 37, 'DRG'), (20, 29, 'ADR')]}),
#  ("i'd gladly trade the mtx headache for humira but after 5 months i still don't have the prescription i function through vitamins & motrin mtx",
#   {'entities': [(137, 140, 'DRG'), (25, 33, 'ADR')]}),
#  ("thank god i was born with so much hair i wouldn't been balm by now crohnsproblems teamibd hairloss humira chronic illness gratitude humira",
#   {'entities': [(132, 138, 'DRG'), (55, 59, 'ADR')]}),
#  ("thank god i was born with so much hair i wouldn't been balm by now crohnsproblems teamibd hairloss humira chronic illness gratitude humira",
#   {'entities': [(132, 138, 'DRG'), (90, 98, 'ADR')]}),
#  ('vyvanse makes me having the sleeping schedule of a vampire vyvanse',
#   {'entities': [(59, 66, 'DRG'), (28, 58, 'ADR')]}),
#  ('1/2 vitamin d malsorption and damaged photosynthesis of sun shine in to vitamin d from levaquin toxicity leading to calcium problems levaquin',
#   {'entities': [(133, 141, 'DRG'), (116, 132, 'ADR')]}),
#  ('1/2 vitamin d malsorption and damaged photosynthesis of sun shine in to vitamin d from levaquin toxicity leading to calcium problems levaquin',
#   {'entities': [(133, 141, 'DRG'), (4, 25, 'ADR')]}),
#  ('but still dr maria jasinskas was right & would have been if not for pharmacy she said "you know sometimes vyvanse can make you depressed" vyvanse',
#   {'entities': [(138, 145, 'DRG'), (127, 136, 'ADR')]}),
#  ('quetiapine was horrific for me in relation to wait gain such a horror story but the weight will come off one day at a time quetiapine',
#   {'entities': [(123, 133, 'DRG'), (46, 55, 'ADR')]}),
#  ('quetiapine was horrific for me in relation to wait gain such a horror story but the weight will come off one day at a time quetiapine',
#   {'entities': [(123, 133, 'DRG'), (84, 90, 'ADR')]}),
#  ('think just lithium for monotherapy & lamotrigine 4 rapidcycling atypicalantipsychotics now revealing serious sideeffects lamotrigine',
#   {'entities': [(121, 132, 'DRG')]}),
#  ("what problems did you have with humira if you don't mind me asking i tried infliximab it destroyed my liver infliximab",
#   {'entities': [(108, 118, 'DRG'), (89, 107, 'ADR')]}),
#  ('me too remicade for a year humira and had an allergic reaction to cimzia almost killed me in november cimzia',
#   {'entities': [(102, 108, 'DRG'), (45, 62, 'ADR')]}),
#  ('me too remicade for a year humira and had an allergic reaction to cimzia almost killed me in november cimzia',
#   {'entities': [(102, 108, 'DRG'), (73, 89, 'ADR')]}),
#  ('sad but over aggressive marketing of juxtapid will probably make it more difficult for true hofh to get covered juxtapid',
#   {'entities': [(112, 120, 'DRG')]}),
#  ('someones said can happen while fighting infection which is quite possible nearly finished some cipro&bringing up foul gunk cipro',
#   {'entities': [(123, 128, 'DRG')]}),
#  ('lexapro gave me the worst mixed episodes i have some instability with pristiq but i can manage it ok lexapro',
#   {'entities': [(101, 108, 'DRG'), (26, 40, 'ADR')]}),
#  ('(( when i used to take trazodone to sleep people would make me stay up after i took it so they could watch me be high )) trazodone',
#   {'entities': [(121, 130, 'DRG'), (113, 117, 'ADR')]}),
#  ('im having paroxetine withdrawals but thats ok cuz i still aint takin no moe fuck behavioral health ill be iight paroxetine',
#   {'entities': [(112, 122, 'DRG'), (21, 32, 'ADR')]}),
#  ('almost blew out my arms & heels @ work they hurt like hell & the pain is spreading damned cipro cipro',
#   {'entities': [(96, 101, 'DRG'), (65, 69, 'ADR')]}),
#  ('almost blew out my arms & heels @ work they hurt like hell & the pain is spreading damned cipro cipro',
#   {'entities': [(96, 101, 'DRG'), (26, 31, 'ADR')]}),
#  ('almost blew out my arms & heels @ work they hurt like hell & the pain is spreading damned cipro cipro',
#   {'entities': [(96, 101, 'DRG'), (44, 48, 'ADR')]}),
#  ('almost blew out my arms & heels @ work they hurt like hell & the pain is spreading damned cipro cipro',
#   {'entities': [(96, 101, 'DRG'), (7, 23, 'ADR')]}),
#  ('adderall makes me vomit and vyvanse gives me migraines the struggle vyvanse',
#   {'entities': [(68, 75, 'DRG'), (45, 54, 'ADR')]}),
#  ('adderall makes me vomit and vyvanse gives me migraines the struggle adderall',
#   {'entities': [(68, 76, 'DRG'), (18, 23, 'ADR')]}),
#  ("the quetiapine is kicking in bizarre thoughts tonight tempted to take the whole lot i won't don't worry people just odd thoughts quetiapine",
#   {'entities': [(129, 139, 'DRG'), (29, 45, 'ADR')]}),
#  ("i'm always irritated on vyvanse because people can't think as fast as i can it's like every conversation is with someone at a nursing home vyvanse",
#   {'entities': [(139, 146, 'DRG'), (47, 66, 'ADR')]}),
#  ("i'm always irritated on vyvanse because people can't think as fast as i can it's like every conversation is with someone at a nursing home vyvanse",
#   {'entities': [(139, 146, 'DRG'), (11, 20, 'ADR')]}),
#  ('try something like wellbutrin there are many better than zoloft (zombie loft) and paxil for anxiety imo zoloft',
#   {'entities': [(104, 110, 'DRG'), (65, 71, 'ADR')]}),
#  ("i fell asleep and woke back up again trying a quarter of a seroquel instead of half this time i'd like to get out of bed tomorrow seroquel",
#   {'entities': [(130, 138, 'DRG'), (106, 120, 'ADR')]}),
#  ("does anyone on tysabri get flu iike symptoms aches and pains shivers a sweats i seem to get it about a week or so after i've had infusion tysabri",
#   {'entities': [(138, 145, 'DRG'), (45, 60, 'ADR')]}),
#  ("does anyone on tysabri get flu iike symptoms aches and pains shivers a sweats i seem to get it about a week or so after i've had infusion tysabri",
#   {'entities': [(138, 145, 'DRG'), (27, 44, 'ADR')]}),
#  ("does anyone on tysabri get flu iike symptoms aches and pains shivers a sweats i seem to get it about a week or so after i've had infusion tysabri",
#   {'entities': [(138, 145, 'DRG'), (61, 68, 'ADR')]}),
#  ("does anyone on tysabri get flu iike symptoms aches and pains shivers a sweats i seem to get it about a week or so after i've had infusion tysabri",
#   {'entities': [(138, 145, 'DRG'), (71, 77, 'ADR')]}),
#  ('rt if this fuckin emt looks at me one more time hes gonna feel the wrath of my vyvanse rage vyvanse',
#   {'entities': [(92, 99, 'DRG'), (87, 91, 'ADR')]}),
#  ('21 55 rivaroxaban diary day 8 aches easing back pain easing swollen lower legs like fluid retention i take 20mg furosemide every a m rivaroxaban',
#   {'entities': [(133, 144, 'DRG'), (30, 35, 'ADR')]}),
#  ('21 55 rivaroxaban diary day 8 aches easing back pain easing swollen lower legs like fluid retention i take 20mg furosemide every a m rivaroxaban',
#   {'entities': [(133, 144, 'DRG'), (43, 52, 'ADR')]}),
#  ('21 55 rivaroxaban diary day 8 aches easing back pain easing swollen lower legs like fluid retention i take 20mg furosemide every a m rivaroxaban',
#   {'entities': [(133, 144, 'DRG'), (84, 99, 'ADR')]}),
#  ('21 55 rivaroxaban diary day 8 aches easing back pain easing swollen lower legs like fluid retention i take 20mg furosemide every a m rivaroxaban',
#   {'entities': [(133, 144, 'DRG'), (60, 78, 'ADR')]}),
#  ('comedown is hell when i went cold turkey from effexor it was about two weeks before the zap noises stopped effexor',
#   {'entities': [(107, 114, 'DRG'), (0, 16, 'ADR')]}),
#  ('comedown is hell when i went cold turkey from effexor it was about two weeks before the zap noises stopped effexor',
#   {'entities': [(107, 114, 'DRG'), (88, 98, 'ADR')]}),
#  ('my effexor has left me with the inability to cry i was dry eyed watching "into the wild" and even one of those sarah mclachlan commercials effexor',
#   {'entities': [(139, 146, 'DRG'), (55, 63, 'ADR')]}),
#  ('my effexor has left me with the inability to cry i was dry eyed watching "into the wild" and even one of those sarah mclachlan commercials effexor',
#   {'entities': [(139, 146, 'DRG'), (32, 48, 'ADR')]}),
#  ("i hate how vyvanse makes me over think everything and it makes me angry about things that i shouldn't even be angry about vyvanse",
#   {'entities': [(122, 129, 'DRG'), (66, 71, 'ADR')]}),
#  ("i hate how vyvanse makes me over think everything and it makes me angry about things that i shouldn't even be angry about vyvanse",
#   {'entities': [(122, 129, 'DRG'), (28, 38, 'ADR')]}),
#  ('too tired to function right now thanks humira naptime humira',
#   {'entities': [(54, 60, 'DRG'), (46, 53, 'ADR')]}),
#  ('too tired to function right now thanks humira naptime humira',
#   {'entities': [(54, 60, 'DRG'), (4, 9, 'ADR')]}),
#  ('rt almost blew out my arms & heels @ work they hurt like hell & the pain is spreading damned cipro cipro',
#   {'entities': [(99, 104, 'DRG'), (68, 72, 'ADR')]}),
#  ('rt almost blew out my arms & heels @ work they hurt like hell & the pain is spreading damned cipro cipro',
#   {'entities': [(99, 104, 'DRG'), (29, 34, 'ADR')]}),
#  ('rt almost blew out my arms & heels @ work they hurt like hell & the pain is spreading damned cipro cipro',
#   {'entities': [(99, 104, 'DRG'), (47, 51, 'ADR')]}),
#  ('rt almost blew out my arms & heels @ work they hurt like hell & the pain is spreading damned cipro cipro',
#   {'entities': [(99, 104, 'DRG'), (10, 26, 'ADR')]}),
#  ('fuckin wired not sleeping tonight vyvanse whatdoido yuuuuup vyvanse',
#   {'entities': [(60, 67, 'DRG'), (13, 25, 'ADR')]}),
#  ('fuckin wired not sleeping tonight vyvanse whatdoido yuuuuup vyvanse',
#   {'entities': [(60, 67, 'DRG'), (7, 12, 'ADR')]}),
#  ('i think some people will try anything sometimes i have with my severe psoriasis finally awaiting humira injection anydayx humira',
#   {'entities': [(122, 128, 'DRG')]}),
#  ('had 2 quit job tendons in lots of pain almost ruptured hands barely usable now damned cipro cipro',
#   {'entities': [(92, 97, 'DRG'), (55, 74, 'ADR')]}),
#  ('had 2 quit job tendons in lots of pain almost ruptured hands barely usable now damned cipro cipro',
#   {'entities': [(92, 97, 'DRG'), (15, 38, 'ADR')]}),
#  ("no med orders til effexor is fully exited still having brain shivers but mostly when i don't eat effexor withdrawal depression effexor",
#   {'entities': [(127, 134, 'DRG'), (55, 68, 'ADR')]}),
#  ("no med orders til effexor is fully exited still having brain shivers but mostly when i don't eat effexor withdrawal depression effexor",
#   {'entities': [(127, 134, 'DRG'), (105, 115, 'ADR')]}),
#  ('did i read in a blog post that you took venlafaxine i am on 300mg and if i forget it for one day i can barely function the next venlafaxine',
#   {'entities': [(128, 139, 'DRG'), (103, 118, 'ADR')]}),
#  ('restless arms & legs blood quetiapine / quetiapine',
#   {'entities': [(40, 50, 'DRG'), (0, 13, 'ADR')]}),
#  ('restless arms & legs blood quetiapine / quetiapine',
#   {'entities': [(40, 50, 'DRG'), (0, 20, 'ADR')]}),
#  ("i've been sleeping most of my day away thanks to my humira shot some days i feel like just giving up sick&tired humira",
#   {'entities': [(112, 118, 'DRG'), (10, 18, 'ADR')]}),
#  ("at my old weight my bmi was 18 4 i hate seroquel and prozac and my new pill i don't eat but still gain weight seroquel",
#   {'entities': [(110, 118, 'DRG'), (98, 109, 'ADR')]}),
#  ("glad to here it's keppra over the others lamictal made me a zombie first seizure is a bitch eh lamictal",
#   {'entities': [(95, 103, 'DRG'), (60, 66, 'ADR')]}),
#  ('rt even w/ humira ab pain cramps nausea vomitting skin&joint problems ulcers in mouth&fatique uclaibdnurses2013 humira',
#   {'entities': [(112, 118, 'DRG'), (18, 25, 'ADR')]}),
#  ('rt even w/ humira ab pain cramps nausea vomitting skin&joint problems ulcers in mouth&fatique uclaibdnurses2013 humira',
#   {'entities': [(112, 118, 'DRG'), (26, 32, 'ADR')]}),
#  ('rt even w/ humira ab pain cramps nausea vomitting skin&joint problems ulcers in mouth&fatique uclaibdnurses2013 humira',
#   {'entities': [(112, 118, 'DRG'), (86, 93, 'ADR')]}),
#  ('rt even w/ humira ab pain cramps nausea vomitting skin&joint problems ulcers in mouth&fatique uclaibdnurses2013 humira',
#   {'entities': [(112, 118, 'DRG'), (55, 69, 'ADR')]}),
#  ('rt even w/ humira ab pain cramps nausea vomitting skin&joint problems ulcers in mouth&fatique uclaibdnurses2013 humira',
#   {'entities': [(112, 118, 'DRG'), (33, 39, 'ADR')]}),
#  ('rt even w/ humira ab pain cramps nausea vomitting skin&joint problems ulcers in mouth&fatique uclaibdnurses2013 humira',
#   {'entities': [(112, 118, 'DRG'), (50, 54, 'ADR')]}),
#  ('rt even w/ humira ab pain cramps nausea vomitting skin&joint problems ulcers in mouth&fatique uclaibdnurses2013 humira',
#   {'entities': [(112, 118, 'DRG'), (70, 85, 'ADR')]}),
#  ('rt even w/ humira ab pain cramps nausea vomitting skin&joint problems ulcers in mouth&fatique uclaibdnurses2013 humira',
#   {'entities': [(112, 118, 'DRG'), (40, 49, 'ADR')]}),
#  ('they probably would have offered me the full anti psychotic menu had i not reacted badly to seroquel handy bonus seroquel',
#   {'entities': [(113, 121, 'DRG'), (75, 88, 'ADR')]}),
#  ('i was prescribed victoza for obesity in july 2010 i have been ill ever since evil drug diabetes victoza',
#   {'entities': [(96, 103, 'DRG'), (62, 65, 'ADR')]}),
#  ('lol good ol anger management my pills are lamotrigine lamotrigine',
#   {'entities': [(54, 65, 'DRG')]}),
#  ('rt vyvanse commonly known as ocd in a pill vyvanse',
#   {'entities': [(43, 50, 'DRG'), (29, 32, 'ADR')]}),
#  ("i'm having to pee way too much this drive drinking too much water fuck you 70mg vyvanse and your ability to dehydrate the fuck out of me vyvanse",
#   {'entities': [(137, 144, 'DRG'), (108, 117, 'ADR')]}),
#  ("i'm having to pee way too much this drive drinking too much water fuck you 70mg vyvanse and your ability to dehydrate the fuck out of me vyvanse",
#   {'entities': [(137, 144, 'DRG'), (14, 30, 'ADR')]}),
#  ('this rant could be paxil withdrawl or delayed divorce rage paxil',
#   {'entities': [(59, 64, 'DRG'), (5, 9, 'ADR')]}),
#  ('this rant could be paxil withdrawl or delayed divorce rage paxil',
#   {'entities': [(59, 64, 'DRG'), (25, 34, 'ADR')]}),
#  ('also yay addiction it\'s drugs i need for living but it\'s still dependance every time i get a "paxil headache" i realize this oh well paxil',
#   {'entities': [(133, 138, 'DRG'), (9, 18, 'ADR')]}),
#  ('also yay addiction it\'s drugs i need for living but it\'s still dependance every time i get a "paxil headache" i realize this oh well paxil',
#   {'entities': [(133, 138, 'DRG'), (63, 73, 'ADR')]}),
#  ('also yay addiction it\'s drugs i need for living but it\'s still dependance every time i get a "paxil headache" i realize this oh well paxil',
#   {'entities': [(133, 138, 'DRG'), (100, 108, 'ADR')]}),
#  ("gotta find an alternative to vyvanse asap i'd rather be sleepy & happy than alert & depressed vyvanse",
#   {'entities': [(94, 101, 'DRG'), (84, 93, 'ADR')]}),
#  ('yeh same bk felt like sumo wrestler on it all time ( think its f****ed me 4life ( ironic as humira is used to treat artheritis humira',
#   {'entities': [(127, 133, 'DRG'), (12, 35, 'ADR')]}),
#  ("okay i took the seroquel and i am resisting the urge to vomit it up i feel disgusting but oh well good times good vibes don't be sad seroquel",
#   {'entities': [(133, 141, 'DRG'), (70, 85, 'ADR')]}),
#  ("okay i took the seroquel and i am resisting the urge to vomit it up i feel disgusting but oh well good times good vibes don't be sad seroquel",
#   {'entities': [(133, 141, 'DRG'), (48, 61, 'ADR')]}),
#  ("why not to take vyvanse late in the day i just cleaned my entire kitchen it's 3am addproblems vyvanse",
#   {'entities': [(94, 101, 'DRG'), (47, 72, 'ADR')]}),
#  ("why not to take vyvanse late in the day i just cleaned my entire kitchen it's 3am addproblems vyvanse",
#   {'entities': [(94, 101, 'DRG'), (78, 81, 'ADR')]}),
#  ("missing a day of meds is never fun i get migraines if i don't get my effexor do you just get super tired effexor",
#   {'entities': [(105, 112, 'DRG'), (41, 50, 'ADR')]}),
#  ("missing a day of meds is never fun i get migraines if i don't get my effexor do you just get super tired effexor",
#   {'entities': [(105, 112, 'DRG'), (99, 104, 'ADR')]}),
#  ("i'm high af on vyvanse vyvanse",
#   {'entities': [(23, 30, 'DRG'), (4, 8, 'ADR')]}),
#  ('re victoza i was prescribed this in 2010 for obesity caused pancreatitis and digestive problems ever since victoza',
#   {'entities': [(107, 114, 'DRG'), (77, 95, 'ADR')]}),
#  ('re victoza i was prescribed this in 2010 for obesity caused pancreatitis and digestive problems ever since victoza',
#   {'entities': [(107, 114, 'DRG'), (60, 72, 'ADR')]}),
#  ('when are you going to do true life i am addicted to vyvanse vyvanse',
#   {'entities': [(60, 67, 'DRG'), (40, 48, 'ADR')]}),
#  ('09 26 day 12 rivaroxaban diary headache right shoulder and neck ache lower back pain weak knees limping when walking taken paracetamol rivaroxaban',
#   {'entities': [(135, 146, 'DRG'), (31, 39, 'ADR')]}),
#  ('09 26 day 12 rivaroxaban diary headache right shoulder and neck ache lower back pain weak knees limping when walking taken paracetamol rivaroxaban',
#   {'entities': [(135, 146, 'DRG'), (69, 84, 'ADR')]}),
#  ('09 26 day 12 rivaroxaban diary headache right shoulder and neck ache lower back pain weak knees limping when walking taken paracetamol rivaroxaban',
#   {'entities': [(135, 146, 'DRG'), (59, 68, 'ADR')]}),
#  ('09 26 day 12 rivaroxaban diary headache right shoulder and neck ache lower back pain weak knees limping when walking taken paracetamol rivaroxaban',
#   {'entities': [(135, 146, 'DRG'), (46, 54, 'ADR')]}),
#  ('09 26 day 12 rivaroxaban diary headache right shoulder and neck ache lower back pain weak knees limping when walking taken paracetamol rivaroxaban',
#   {'entities': [(135, 146, 'DRG'), (85, 95, 'ADR')]}),
#  ('09 26 day 12 rivaroxaban diary headache right shoulder and neck ache lower back pain weak knees limping when walking taken paracetamol rivaroxaban',
#   {'entities': [(135, 146, 'DRG'), (96, 103, 'ADR')]}),
#  ("though i'm still sleeping well even on floor that much be because of long half life and still having fluoxetine in my system fluoxetine",
#   {'entities': [(125, 135, 'DRG')]}),
#  ('get asked if i have tourettes nope just vyvanse twitchy vyvanse',
#   {'entities': [(56, 63, 'DRG'), (20, 29, 'ADR')]}),
#  ('get asked if i have tourettes nope just vyvanse twitchy vyvanse',
#   {'entities': [(56, 63, 'DRG'), (48, 55, 'ADR')]}),
#  ("i don't know whether my vyvanse caused my caffeine addiction or caffeine caused my vyvanse addiction vyvanse",
#   {'entities': [(101, 108, 'DRG'), (51, 60, 'ADR')]}),
#  ("rt i don't know whether my vyvanse caused my caffeine addiction or caffeine caused my vyvanse addiction vyvanse",
#   {'entities': [(104, 111, 'DRG'), (54, 63, 'ADR')]}),
#  ('triple drug comparable to mtx + etanercept except on radiographic progression hence too early to conclude rheum eular2013 etanercept',
#   {'entities': [(122, 132, 'DRG')]}),
#  ('my house smells of bacon & seroquel is making me so hungry i want to tear my own face off & eat it or cry or maybe both at once seroquel',
#   {'entities': [(128, 136, 'DRG'), (102, 105, 'ADR')]}),
#  ('my house smells of bacon & seroquel is making me so hungry i want to tear my own face off & eat it or cry or maybe both at once seroquel',
#   {'entities': [(128, 136, 'DRG'), (52, 58, 'ADR')]}),
#  ('my house smells of bacon & seroquel is making me so hungry i want to tear my own face off & eat it or cry or maybe both at once seroquel',
#   {'entities': [(128, 136, 'DRG'), (69, 98, 'ADR')]}),
#  ("yup quetiapine the normal dose at night whacks me out i'd have been asleep til friday on double quetiapine",
#   {'entities': [(96, 106, 'DRG'), (40, 53, 'ADR')]}),
#  ("yup quetiapine the normal dose at night whacks me out i'd have been asleep til friday on double quetiapine",
#   {'entities': [(96, 106, 'DRG'), (68, 74, 'ADR')]}),
#  ("i'm not sure if excedrin is the right way for me to go for my tmj headaches vyvanse + caffeine is pretty rough ideas vyvanse",
#   {'entities': [(117, 124, 'DRG'), (66, 75, 'ADR')]}),
#  ("i'm not sure if excedrin is the right way for me to go for my tmj headaches vyvanse + caffeine is pretty rough ideas vyvanse",
#   {'entities': [(117, 124, 'DRG'), (62, 65, 'ADR')]}),
#  ('13 08 day 13 rivaroxaban diary pracetamol has taken away most of the aches but still have lower back ache and weak knees rivaroxaban',
#   {'entities': [(121, 132, 'DRG'), (69, 74, 'ADR')]}),
#  ('13 08 day 13 rivaroxaban diary pracetamol has taken away most of the aches but still have lower back ache and weak knees rivaroxaban',
#   {'entities': [(121, 132, 'DRG'), (90, 105, 'ADR')]}),
#  ('13 08 day 13 rivaroxaban diary pracetamol has taken away most of the aches but still have lower back ache and weak knees rivaroxaban',
#   {'entities': [(121, 132, 'DRG'), (110, 120, 'ADR')]}),
#  ('quetiapine or olanzapine for mild to moderate anxiety older persons mental health olanzapine',
#   {'entities': [(82, 92, 'DRG')]}),
#  ('cant cope coming off venlafaxine feel like iv got a hangover mixed with flu symptoms total nausea & i cant keep still please hurry & pass venlafaxine',
#   {'entities': [(138, 149, 'DRG'), (10, 20, 'ADR')]}),
#  ('cant cope coming off venlafaxine feel like iv got a hangover mixed with flu symptoms total nausea & i cant keep still please hurry & pass venlafaxine',
#   {'entities': [(138, 149, 'DRG'), (72, 84, 'ADR')]}),
#  ('cant cope coming off venlafaxine feel like iv got a hangover mixed with flu symptoms total nausea & i cant keep still please hurry & pass venlafaxine',
#   {'entities': [(138, 149, 'DRG'), (52, 60, 'ADR')]}),
#  ('cant cope coming off venlafaxine feel like iv got a hangover mixed with flu symptoms total nausea & i cant keep still please hurry & pass venlafaxine',
#   {'entities': [(138, 149, 'DRG'), (91, 97, 'ADR')]}),
#  ('cant cope coming off venlafaxine feel like iv got a hangover mixed with flu symptoms total nausea & i cant keep still please hurry & pass venlafaxine',
#   {'entities': [(138, 149, 'DRG'), (102, 117, 'ADR')]}),
#  ("i don't know that one but metho made me sick everyday i took it i had to stop enbrel has worked wonders for me so far metho",
#   {'entities': [(118, 123, 'DRG'), (40, 44, 'ADR')]}),
#  ("i'm allergic to enbrel ( bad reaction enbrel",
#   {'entities': [(38, 44, 'DRG'), (4, 12, 'ADR')]}),
#  ("rt i don't know that one but metho made me sick everyday i took it i had to stop enbrel has worked wonders for m metho",
#   {'entities': [(113, 118, 'DRG'), (43, 47, 'ADR')]}),
#  ('just wondering where the side effect of hating the world is stated on vyvanse advertisements vyvanse',
#   {'entities': [(93, 100, 'DRG'), (40, 56, 'ADR')]}),
#  ('this lamictal shit ain\'t cuttin the mustard any "mood stabilizers" that don\'t steal your soul & make u a bloated zombie a la britney lamictal',
#   {'entities': [(133, 141, 'DRG'), (105, 112, 'ADR')]}),
#  ('this lamictal shit ain\'t cuttin the mustard any "mood stabilizers" that don\'t steal your soul & make u a bloated zombie a la britney lamictal',
#   {'entities': [(133, 141, 'DRG'), (78, 93, 'ADR')]}),
#  ('this lamictal shit ain\'t cuttin the mustard any "mood stabilizers" that don\'t steal your soul & make u a bloated zombie a la britney lamictal',
#   {'entities': [(133, 141, 'DRG'), (113, 119, 'ADR')]}),
#  ('ssris were great for me for ages not working as well now thus seroquel i m also on clonazepam makes me sleepy too seroquel',
#   {'entities': [(114, 122, 'DRG'), (33, 52, 'ADR')]}),
#  ('ssris were great for me for ages not working as well now thus seroquel i m also on clonazepam makes me sleepy too seroquel',
#   {'entities': [(114, 122, 'DRG'), (103, 109, 'ADR')]}),
#  ('cipro and flagyl are the absolute worst like taking rat poison cipro',
#   {'entities': [(63, 68, 'DRG'), (40, 62, 'ADR')]}),
#  ("have decided to skip my humira shot today my body's having hysterics need time to simmer down rheum humira",
#   {'entities': [(100, 106, 'DRG')]}),
#  ('i tried baclofen another common muscle relaxer and had too many side effects from it including worsening pain baclofen',
#   {'entities': [(110, 118, 'DRG'), (95, 109, 'ADR')]}),
#  ('i heard of tysabri should work good on ms but serious side effects as well ( tysabri',
#   {'entities': [(77, 84, 'DRG')]}),
#  ('the effexor may have been pushing me toward hypomania so we are trying just an ssri then see if a mood stabilizer is needed effexor',
#   {'entities': [(124, 131, 'DRG'), (44, 53, 'ADR')]}),
#  ("seroquel left me with sleep paralysis abilify left me with occasional muscle spasms i've been off of both for nearly a decade abilify",
#   {'entities': [(126, 133, 'DRG'), (70, 83, 'ADR')]}),
#  ("seroquel left me with sleep paralysis abilify left me with occasional muscle spasms i've been off of both for nearly a decade seroquel",
#   {'entities': [(126, 134, 'DRG'), (22, 37, 'ADR')]}),
#  ('took my lamotrigine (14) at 1704 utc long drive ahead of me today hope my back pain goes away lamotrigine',
#   {'entities': [(94, 105, 'DRG')]}),
#  ('ugh the olanzapine makes me so tired ( olanzapine',
#   {'entities': [(39, 49, 'DRG'), (31, 36, 'ADR')]}),
#  ('when i weaned myself off paxil slower than recommended my blood pressure dropped so bad i couldn t walk for a week paxil',
#   {'entities': [(115, 120, 'DRG'), (58, 80, 'ADR')]}),
#  ('when i weaned myself off paxil slower than recommended my blood pressure dropped so bad i couldn t walk for a week paxil',
#   {'entities': [(115, 120, 'DRG'), (90, 103, 'ADR')]}),
#  ("gimme one reason why i shouldn't have sex drive / libido i accept this as a part of withdrawal symptoms from venlafaxine o venlafaxine",
#   {'entities': [(123, 134, 'DRG'), (84, 94, 'ADR')]}),
#  ("gimme one reason why i shouldn't have sex drive / libido i accept this as a part of withdrawal symptoms from venlafaxine o venlafaxine",
#   {'entities': [(123, 134, 'DRG'), (50, 56, 'ADR')]}),
#  ("gimme one reason why i shouldn't have sex drive / libido i accept this as a part of withdrawal symptoms from venlafaxine o venlafaxine",
#   {'entities': [(123, 134, 'DRG'), (38, 47, 'ADR')]}),
#  ('4 types of medicine 2 types of lozenge spoonful of honey and now ice any other cough remedies lozenge',
#   {'entities': [(94, 101, 'DRG')]}),
#  ("i called for my effexor refill on wednesday i was out it's sunday and i can't stop screaming and crying effexor",
#   {'entities': [(104, 111, 'DRG'), (97, 103, 'ADR')]}),
#  ("i called for my effexor refill on wednesday i was out it's sunday and i can't stop screaming and crying effexor",
#   {'entities': [(104, 111, 'DRG'), (83, 92, 'ADR')]}),
#  ("arms stil hurt cipro to tendons is like a razor to rope cut it partway through makes it weaker & won't heal ever damned cipro cipro",
#   {'entities': [(126, 131, 'DRG'), (0, 14, 'ADR')]}),
#  ("arms stil hurt cipro to tendons is like a razor to rope cut it partway through makes it weaker & won't heal ever damned cipro cipro",
#   {'entities': [(126, 131, 'DRG'), (24, 55, 'ADR')]}),
#  ("arms stil hurt cipro to tendons is like a razor to rope cut it partway through makes it weaker & won't heal ever damned cipro cipro",
#   {'entities': [(126, 131, 'DRG'), (88, 94, 'ADR')]}),
#  ("arms stil hurt cipro to tendons is like a razor to rope cut it partway through makes it weaker & won't heal ever damned cipro cipro",
#   {'entities': [(126, 131, 'DRG'), (97, 107, 'ADR')]}),
#  ('eurgh last time i was this tired i was on a four day antidepressant cocktail binge seroxat sertraline fluoxitine lithium fluoxetine',
#   {'entities': [(121, 131, 'DRG'), (27, 32, 'ADR')]}),
#  ("rivaroxaban 2/2 lower back pain not very pc but am crippled by this drug taking more paracetamols must ring for 'phone consultation rivaroxaban",
#   {'entities': [(132, 143, 'DRG'), (16, 31, 'ADR')]}),
#  ("rivaroxaban 2/2 lower back pain not very pc but am crippled by this drug taking more paracetamols must ring for 'phone consultation rivaroxaban",
#   {'entities': [(132, 143, 'DRG'), (51, 59, 'ADR')]}),
#  ('i was on enbrel for 8 years have since developed neuro problems (ataxia) wish id never taken it side effects not worth risks enbrel',
#   {'entities': [(125, 131, 'DRG'), (65, 71, 'ADR')]}),
#  ('i was on enbrel for 8 years have since developed neuro problems (ataxia) wish id never taken it side effects not worth risks enbrel',
#   {'entities': [(125, 131, 'DRG'), (49, 63, 'ADR')]}),
#  ('i essentially felt nothing on them great for anxiety bad for living coming off klonopin and paxil was hell though paxil',
#   {'entities': [(114, 119, 'DRG'), (68, 106, 'ADR')]}),
#  ('i essentially felt nothing on them great for anxiety bad for living coming off klonopin and paxil was hell though paxil',
#   {'entities': [(114, 119, 'DRG'), (14, 26, 'ADR')]}),
#  ('well i m taking it with a mood stabilizer (lamictal) i can t take anti depressants by themselves triggers my rapid cycling lamictal',
#   {'entities': [(123, 131, 'DRG'), (97, 122, 'ADR')]}),
#  ('i think it was an anxiety meds dream damn quetiapine quetiapine',
#   {'entities': [(53, 63, 'DRG'), (31, 36, 'ADR')]}),
#  ('quetiapine very low dose even with increase helps me get to sleep (& eat in general) but feel really groggy in the morning quetiapine',
#   {'entities': [(123, 133, 'DRG'), (101, 122, 'ADR')]}),
#  ('03 00 day 19 rivaroxaban diary just taken 2 paracetamol probabably will take 70 minutes to work a long painful night ahead rivaroxaban',
#   {'entities': [(123, 134, 'DRG'), (103, 110, 'ADR')]}),
#  ('rt humira injection psoriasis gone2 board&funding chief pharmacist reject cause derm doc not tried accetrine c humira',
#   {'entities': [(111, 117, 'DRG')]}),
#  ('your humira shot burns with the power of a thousand suns ibdfmlmoments crohns ibd uc humira',
#   {'entities': [(85, 91, 'DRG'), (17, 22, 'ADR')]}),
#  ('today is the day for my biweekly humira injection any volunteers to take it for me it hurts humira',
#   {'entities': [(92, 98, 'DRG'), (86, 91, 'ADR')]}),
#  ("new dx dysthymia start seroquel (which i've had before it zombified me iirc) seroquel",
#   {'entities': [(77, 85, 'DRG'), (58, 67, 'ADR')]}),
#  ("depakote made me feel flat but helps many zyprexa can cause weight gain so be very careful i can't tolerate it zyprexa",
#   {'entities': [(111, 118, 'DRG'), (60, 71, 'ADR')]}),
#  ('takin anbien &seroquel for bad insomnia gives u messed up dreams doc saids its normal seroquel',
#   {'entities': [(86, 94, 'DRG'), (48, 64, 'ADR')]}),
#  ('been on humira now short period 4 to 6 injections no noticeable change in pain but racing heart and palpitations mtx at 1ml injection humira',
#   {'entities': [(134, 140, 'DRG'), (83, 95, 'ADR')]}),
#  ('been on humira now short period 4 to 6 injections no noticeable change in pain but racing heart and palpitations mtx at 1ml injection humira',
#   {'entities': [(134, 140, 'DRG'), (100, 112, 'ADR')]}),
#  ('hey not sleeping hotflashes menopause effexor effexor',
#   {'entities': [(46, 53, 'DRG'), (4, 16, 'ADR')]}),
#  ('i think it s an snri i m not even sure it s viibryd but none of my anti depressants have ever messed me up like this before viibryd',
#   {'entities': [(124, 131, 'DRG'), (94, 106, 'ADR')]}),
#  ('19 32 day 20 rivaroxaban diary still residual aches and pains only had 4 paracetamol today rivaroxaban',
#   {'entities': [(91, 102, 'DRG'), (46, 51, 'ADR')]}),
#  ('19 32 day 20 rivaroxaban diary still residual aches and pains only had 4 paracetamol today rivaroxaban',
#   {'entities': [(91, 102, 'DRG'), (56, 61, 'ADR')]}),
#  ('i better go to bed effexor withdrawal makes me feel kinda terrible ugh effexor',
#   {'entities': [(71, 78, 'DRG'), (47, 66, 'ADR')]}),
#  ('i better go to bed effexor withdrawal makes me feel kinda terrible ugh effexor',
#   {'entities': [(71, 78, 'DRG'), (27, 37, 'ADR')]}),
#  ("so i finally have my 1st infusion of tysabri set for nxt fri so i'm supposed to suffer until it kicks in this relapse is relentless tysabri",
#   {'entities': [(132, 139, 'DRG')]}),
#  ('just got him from seeing my cf dr no collapse or pneumonia start of a flare up probably so 2 weeks of oral cipro cipro',
#   {'entities': [(113, 118, 'DRG')]}),
#  ('i was on quetiapine and gained 40lbs <wall> so i am not even trying olanzapine they gave me abilify cause it not supposed to quetiapine',
#   {'entities': [(125, 135, 'DRG'), (24, 36, 'ADR')]}),
#  ("i 'served' 6months of fluoxetine time around 18 years ago it put a smile on my face but inside i was still screaming ( fluoxetine",
#   {'entities': [(119, 129, 'DRG'), (88, 116, 'ADR')]}),
#  ('what i take is serious i never was informed ahead of time i could get "metabolic" syndrome from seroquel seroquel',
#   {'entities': [(105, 113, 'DRG'), (-1, 19, 'ADR')]}),
#  ('half of seroquel knocks me out so fast and im asleep for at least 10 hours seroquel',
#   {'entities': [(75, 83, 'DRG'), (17, 30, 'ADR')]}),
#  ('08 55 day 21 rivaroxaban diary strange muscle spasms especially in neck shoulders and legs no more fluid retention more mobile rivaroxaban',
#   {'entities': [(127, 138, 'DRG'), (99, 114, 'ADR')]}),
#  ('08 55 day 21 rivaroxaban diary strange muscle spasms especially in neck shoulders and legs no more fluid retention more mobile rivaroxaban',
#   {'entities': [(127, 138, 'DRG'), (120, 126, 'ADR')]}),
#  ('08 55 day 21 rivaroxaban diary strange muscle spasms especially in neck shoulders and legs no more fluid retention more mobile rivaroxaban',
#   {'entities': [(127, 138, 'DRG'), (39, 52, 'ADR')]}),
#  ('epilepsy is sucktastic neuro appt monday to discuss a third med after getting the rash with lamotrigine and the glaucoma with topiramate lamotrigine',
#   {'entities': [(137, 148, 'DRG'), (82, 86, 'ADR')]}),
#  ('epilepsy is sucktastic neuro appt monday to discuss a third med after getting the rash with lamotrigine and the glaucoma with topiramate topiramate',
#   {'entities': [(137, 147, 'DRG'), (112, 120, 'ADR')]}),
#  ('i still get the pins & needles feeling in my hands since doing humira humira',
#   {'entities': [(70, 76, 'DRG'), (16, 30, 'ADR')]}),
#  ('my step dad was on effexer taking supplements for energy and drinking like a fish when he shot my daughter&me effexor',
#   {'entities': [(110, 117, 'DRG'), (90, 106, 'ADR')]}),
#  ('this seroquel got me lo0o0py as helll this status took me at least thirty minutes to type i keep waking up without knowing i feel asleep seroquel',
#   {'entities': [(137, 145, 'DRG'), (67, 89, 'ADR')]}),
#  ('this seroquel got me lo0o0py as helll this status took me at least thirty minutes to type i keep waking up without knowing i feel asleep seroquel',
#   {'entities': [(137, 145, 'DRG'), (21, 28, 'ADR')]}),
#  ('this seroquel got me lo0o0py as helll this status took me at least thirty minutes to type i keep waking up without knowing i feel asleep seroquel',
#   {'entities': [(137, 145, 'DRG'), (97, 136, 'ADR')]}),
#  ('rivaroxaban diary day 22 am beginning to think all pains from pressure on that part of body are due to fluid retention rivaroxaban',
#   {'entities': [(119, 130, 'DRG'), (103, 118, 'ADR')]}),
#  ('rivaroxaban diary day 22 am beginning to think all pains from pressure on that part of body are due to fluid retention rivaroxaban',
#   {'entities': [(119, 130, 'DRG'), (51, 56, 'ADR')]}),
#  ("natural don't work for me try 300mg of seroquel you'll sleep for days i have insomnia that's what they give me lol seroquel",
#   {'entities': [(115, 123, 'DRG'), (55, 69, 'ADR')]}),
#  ('doc for panic disorders alprazolam (addictive) and paroxetine (sedating) psychiatry alprazolam',
#   {'entities': [(84, 94, 'DRG'), (36, 45, 'ADR')]}),
#  ('doc for panic disorders alprazolam (addictive) and paroxetine (sedating) psychiatry paroxetine',
#   {'entities': [(84, 94, 'DRG'), (63, 71, 'ADR')]}),
#  ('dude i feel physically and mentally drained thats the paxil i wanted hard at work paxil',
#   {'entities': [(82, 87, 'DRG'), (12, 22, 'ADR')]}),
#  ('dude i feel physically and mentally drained thats the paxil i wanted hard at work paxil',
#   {'entities': [(82, 87, 'DRG'), (27, 43, 'ADR')]}),
#  ("given what we know about the demographics of type 2 i'm a bit surprised she's still all over the victoza page victoza",
#   {'entities': [(110, 117, 'DRG')]}),
#  ('she announced she had type 2 diabetes on the day she endorsed the diabetes drug victoza and a lucrative collaboration with the manufacturer victoza',
#   {'entities': [(140, 147, 'DRG')]}),
#  ('someone back me up to about what a trauma when you have to dispense 20 lots of rifampicin and cipro for meningitis prophylaxis cipro',
#   {'entities': [(127, 132, 'DRG')]}),
#  ('04 46 day 23 rivaroxaban diary much better than yesterday still neck back hip and leg aches but not so intense rivaroxaban',
#   {'entities': [(111, 122, 'DRG'), (69, 91, 'ADR')]}),
#  ('04 46 day 23 rivaroxaban diary much better than yesterday still neck back hip and leg aches but not so intense rivaroxaban',
#   {'entities': [(111, 122, 'DRG'), (82, 91, 'ADR')]}),
#  ('04 46 day 23 rivaroxaban diary much better than yesterday still neck back hip and leg aches but not so intense rivaroxaban',
#   {'entities': [(111, 122, 'DRG'), (64, 91, 'ADR')]}),
#  ('04 46 day 23 rivaroxaban diary much better than yesterday still neck back hip and leg aches but not so intense rivaroxaban',
#   {'entities': [(111, 122, 'DRG'), (74, 91, 'ADR')]}),
#  ('smh lmao paxil was my first i just stopped effexor (the headaches were a nightmare) effexor',
#   {'entities': [(84, 91, 'DRG'), (56, 65, 'ADR')]}),
#  ("the toilet just flushed itself my apartment is haunted paxil tells me it's common for apartments to be haunted send help paxil",
#   {'entities': [(121, 126, 'DRG'), (75, 110, 'ADR')]}),
#  ("i do have a crisis number but i'm just going to knock myself out today w/ trazodone and start antipsychotics today too trazodone",
#   {'entities': [(119, 128, 'DRG'), (94, 108, 'ADR')]}),
#  ("try dexter going to knock myself out w/ trazodone and start antipschotucs today fortune'y they work quickly trazodone",
#   {'entities': [(108, 117, 'DRG')]}),
#  ('wish it was monday seeing doctor tomorrow & want to see if he has any suggestions for my withdrawal paroxetine anxiety fedup paroxetine',
#   {'entities': [(125, 135, 'DRG'), (89, 99, 'ADR')]}),
#  ("15 15 rivaroxaban diary day 24 pains easing all the time didn't take losartan yesterday will get bp and hopefully inr checked today rivaroxaban",
#   {'entities': [(132, 143, 'DRG'), (31, 36, 'ADR')]}),
#  ("feels like one of those 5 cup coffee days but wait i'm weaning off seroquel aha seroquel",
#   {'entities': [(80, 88, 'DRG'), (0, 41, 'ADR')]}),
#  ('the most upsetting thing about silver linings playbook is how bradley cooper can take seroquel and still stay in shape seroquel',
#   {'entities': [(119, 127, 'DRG'), (105, 118, 'ADR')]}),
#  ('then the viibryd it will be the hardest makes you very ill hospital ill viibryd',
#   {'entities': [(72, 79, 'DRG'), (21, 24, 'ADR')]}),
#  ('*the fifth bottle paxil her notes "antidepressant good daily medication especially going out in public" she take one immediately * paxil',
#   {'entities': [(131, 136, 'DRG')]}),
#  ('effexor dreams now with lucidity i grant the power of flight effexor',
#   {'entities': [(61, 68, 'DRG'), (24, 32, 'ADR')]}),
#  ('my dreams became vivider i think with effexor bpdchat effexor',
#   {'entities': [(54, 61, 'DRG'), (3, 24, 'ADR')]}),
#  ('bombed on olanzapine work going to be tricky 5 days of not drinking coming up i could sleep all the time atm olanzapine',
#   {'entities': [(109, 119, 'DRG'), (86, 104, 'ADR')]}),
#  ('bombed on olanzapine work going to be tricky 5 days of not drinking coming up i could sleep all the time atm olanzapine',
#   {'entities': [(109, 119, 'DRG'), (0, 6, 'ADR')]}),
#  ('i agree that the after sting is much worse from humira than enbrel rheum humira',
#   {'entities': [(73, 79, 'DRG'), (17, 28, 'ADR')]}),
#  ("i couldn't take lamictal 1 week into it i got the rash a rush trip to the er 6 months till rash was gone lamictal",
#   {'entities': [(105, 113, 'DRG'), (50, 54, 'ADR')]}),
#  ("i didn't expect that going off of paxil would make me want to look at my farrah fawcett poster quite so much paxil",
#   {'entities': [(109, 114, 'DRG'), (62, 94, 'ADR')]}),
#  ('panic attacking because you cant find your effexor and know withdrawal will set in momentarily <<<<<<< effexor',
#   {'entities': [(103, 110, 'DRG'), (60, 70, 'ADR')]}),
#  ("i'm not even sure what to request / sertraline makes me sick now venlafaxine made me sick reboxetine and citalopram useless venlafaxine",
#   {'entities': [(124, 135, 'DRG'), (56, 60, 'ADR')]}),
#  ('question time crohns ibd humira does anyone suffer from egg burps what works for you humira',
#   {'entities': [(85, 91, 'DRG'), (56, 65, 'ADR')]}),
#  ("i'm so fine today increasing zyprexa my condisition became so good it has a side effect that increase my weight i must care about it zyprexa",
#   {'entities': [(133, 140, 'DRG'), (93, 111, 'ADR')]}),
#  ('every time i forget seroquel i end up rage breaking things eg my laptop *facepalm* seroquel',
#   {'entities': [(83, 91, 'DRG'), (38, 58, 'ADR')]}),
#  ('being sick every morning is getting really old not sure if anxiety or my body getting used to paxil anyone know paxil',
#   {'entities': [(112, 117, 'DRG'), (6, 10, 'ADR')]}),
#  ("i can't wait to go get my anti nauaea meds tonight i feel like shit humira is definitely kicking my ass but my skin lools great humira",
#   {'entities': [(128, 134, 'DRG'), (89, 103, 'ADR')]}),
# ...
#  ('life sucks cymbalta can help or cause you to be suicidal commercials',
#   {'entities': []}),
#  ('caep13 q role for tranexamic acid in massive gi bleed on dabigatran room divided but panel supports last ditch effort weak evidence',
#   {'entities': []}),
#  ('i just retweeted some cardiology news regarding dabigatran & post af ablation to make u feel at home lol',
#   {'entities': []}),
#  ('not sure i follow are you encouraging antiplatelet use with dabigatran',
#   {'entities': []}),
#  ('yup tho wonder if this is increased risk w/ dabigatran vs loss of protection from coumadin',
#   {'entities': []}),
#  ('rt report a fixed dose regimen of dabigatran for ischemic stroke may be ineffective in pts with severe obesity',
#   {'entities': []}),
#  ('rt report a fixed dose regimen of dabigatran for ischemic stroke may be ineffective in pts with severe obesity',
#   {'entities': []}),
#  ('rt report a fixed dose regimen of dabigatran for ischemic stroke may be ineffective in pts with severe obesity',
#   {'entities': []}),
#  ('rt rt dabigatran submitted to ema for acute treatment & prevention of recurrent dvt pulmonaryembolism',
#   {'entities': []}),
#  ('isth2013 metaanalysis of dabigatran etexilate clearly induces risk of myocardial infarction',
#   {'entities': []}),
#  ('rt press organising your isth2013 diary oral presentation on measurement of dabigatran plasma concentration eposter 4 53',
#   {'entities': []}),
#  ('osteonecrosis of jaw with denosumab 3cases in yr1 3 vs 5cases in yr4 7 eular2013 osteoporosis',
#   {'entities': []}),
#  ('rt (ann pharmacother) the role of denosumab for prevention of skeletal related complications in multiple myeloma',
#   {'entities': []}),
#  ('i am on duloxetine and i think my body would be asleep 24/7 if i let it duloxetine',
#   {'entities': [(72, 82, 'DRG'), (48, 59, 'ADR')]}),
#  ('i take duloxetine for mine )', {'entities': []}),
#  ('jama 2013 duloxetine no difference initially but demonstrated with crossover decrease was only 0 73 on a 10 point pain scale asco',
#   {'entities': []}),
#  ('i hav to come of the duloxetine immediately as i hav a terrible rash because of it had the rash 2 weeks duloxetine',
#   {'entities': [(104, 114, 'DRG'), (64, 68, 'ADR')]}),
#  ('effexor lawsuits involving heart birth defects removed to federal court effexor news antidepressants',
#   {'entities': []}),
#  ("i'd rather be on the effexor that made me happy though i had severe back pain from it than sad and crying for no reason on lexapro effexor",
#   {'entities': [(131, 138, 'DRG'), (68, 77, 'ADR')]}),
#  ("i'd rather be on the effexor that made me happy though i had severe back pain from it than sad and crying for no reason on lexapro effexor",
#   {'entities': [(131, 138, 'DRG'), (99, 105, 'ADR')]}),
#  ("i'd rather be on the effexor that made me happy though i had severe back pain from it than sad and crying for no reason on lexapro effexor",
#   {'entities': [(131, 138, 'DRG'), (91, 94, 'ADR')]}),
#  ('kinda worried about the nighttime jaw clenching from effexor what with my tongue ring and all l effexor',
#   {'entities': [(96, 103, 'DRG'), (34, 47, 'ADR')]}),
#  ("day one felt a lot longer than the 8 hours i've been awake but i fucking made it motherfuckers i am effexor free feelsgoodman",
#   {'entities': []}),
#  ("i'm on quite high dose of effexor works well often you have to up the dose before giving up on it",
#   {'entities': []}),
#  ("i know things in life could be easier with diazapam tremazepam effexor fluoxetide but it wouldn't solve the problem alwaysthehardway",
#   {'entities': []}),
#  ("my old ones took 2 days for withdrawals but effexor which i'm on now i will get them the next day / i wish i could email you valium effexor",
#   {'entities': [(132, 139, 'DRG'), (28, 39, 'ADR')]}),
#  ('i recently stopped taking effexor 225 what can i do to ease my withdrawls i feel miserable right now and very angry please any ideas effexor',
#   {'entities': [(133, 140, 'DRG'), (110, 115, 'ADR')]}),
#  ('i recently stopped taking effexor 225 what can i do to ease my withdrawls i feel miserable right now and very angry please any ideas effexor',
#   {'entities': [(133, 140, 'DRG'), (81, 90, 'ADR')]}),
#  ('i recently stopped taking effexor 225 what can i do to ease my withdrawls i feel miserable right now and very angry please any ideas effexor',
#   {'entities': [(133, 140, 'DRG'), (63, 73, 'ADR')]}),
#  ('so it fucking turns out that a side effect of effexor is a loss of appetite effexor',
#   {'entities': [(76, 83, 'DRG'), (59, 75, 'ADR')]}),
#  ('drinking on effexor can lead to fatal overdose it is considered more dangerous than drinking on benzos',
#   {'entities': []}),
#  ('the shaking is a common side effect of effexor effexor',
#   {'entities': [(47, 54, 'DRG'), (4, 11, 'ADR')]}),
#  ('day five of no effexor i am guessing this is what it feels like when you come off heroin discontinuation effexor',
#   {'entities': [(105, 112, 'DRG'), (53, 88, 'ADR')]}),
#  ("tell 'em you're suicidal without effexor gimme", {'entities': []}),
#  ('stopping effexor is probably good but not suddenly xxx', {'entities': []}),
#  ('with effexor if i miss one day i am dizzy and wrecked effexor',
#   {'entities': [(54, 61, 'DRG'), (36, 41, 'ADR')]}),
#  ('with effexor if i miss one day i am dizzy and wrecked effexor',
#   {'entities': [(54, 61, 'DRG'), (46, 53, 'ADR')]}),
#  ("oh god yeah effexor is a med where skipping a single dose wrecks you because it doesn't stay in your system",
#   {'entities': []}),
#  ('oh it sucks but try doing snri withdrawal they had to put me on a whole other drug just to get me off effexor ( effexor',
#   {'entities': [(112, 119, 'DRG'), (31, 41, 'ADR')]}),
#  ('brain zaps happens a lot when missing doses (especially with effexor & wellbutrin ime) just feels weird no real danger effexor',
#   {'entities': [(119, 126, 'DRG'), (0, 10, 'ADR')]}),
#  ("i've been having them today too three days without effexor i completely understand what you mean every hit lightheaded effexor",
#   {'entities': [(119, 126, 'DRG'), (107, 118, 'ADR')]}),
#  ('i hated effexor it makes you hungry dizzy and lethargic that culminated in a large weight gain for me effexor',
#   {'entities': [(102, 109, 'DRG'), (36, 41, 'ADR')]}),
#  ('i hated effexor it makes you hungry dizzy and lethargic that culminated in a large weight gain for me effexor',
#   {'entities': [(102, 109, 'DRG'), (29, 35, 'ADR')]}),
#  ('i hated effexor it makes you hungry dizzy and lethargic that culminated in a large weight gain for me effexor',
#   {'entities': [(102, 109, 'DRG'), (46, 55, 'ADR')]}),
#  ('i hated effexor it makes you hungry dizzy and lethargic that culminated in a large weight gain for me effexor',
#   {'entities': [(102, 109, 'DRG'), (83, 94, 'ADR')]}),
#  ('stopped zoloft cold turkey after i became suicidal stopped effexor because i was numb effexor',
#   {'entities': [(86, 93, 'DRG'), (81, 85, 'ADR')]}),
#  ('stopped zoloft cold turkey after i became suicidal stopped effexor because i was numb effexor',
#   {'entities': [(86, 93, 'DRG'), (42, 50, 'ADR')]}),
#  ('effexor withdrawal effexor',
#   {'entities': [(19, 26, 'DRG'), (8, 18, 'ADR')]}),
#  ("i can't stop crying it will never get fucking better and i've enough i'll get all of my effexor and all of my xanax and all of my vivance",
#   {'entities': []}),
#  ('upped my effexor dosage 5 days ago sleep cycle and quality went to shit 4 days ago i sense a correlation here effexor',
#   {'entities': [(110, 117, 'DRG'), (51, 58, 'ADR')]}),
#  ('upped my effexor dosage 5 days ago sleep cycle and quality went to shit 4 days ago i sense a correlation here effexor',
#   {'entities': [(110, 117, 'DRG'), (35, 46, 'ADR')]}),
#  ('stomach discomfort flushed sweating weird jaw this stuff sucks effexor experiment effexor',
#   {'entities': [(82, 89, 'DRG'), (0, 18, 'ADR')]}),
#  ('stomach discomfort flushed sweating weird jaw this stuff sucks effexor experiment effexor',
#   {'entities': [(82, 89, 'DRG'), (19, 26, 'ADR')]}),
#  ('stomach discomfort flushed sweating weird jaw this stuff sucks effexor experiment effexor',
#   {'entities': [(82, 89, 'DRG'), (42, 45, 'ADR')]}),
#  ('stomach discomfort flushed sweating weird jaw this stuff sucks effexor experiment effexor',
#   {'entities': [(82, 89, 'DRG'), (27, 35, 'ADR')]}),
#  ('i love this effexor majorly kills my libido effexor',
#   {'entities': [(44, 51, 'DRG'), (28, 43, 'ADR')]}),
#  ('effexor was a boner killer absolutely welbutrin goes the other way effexor',
#   {'entities': [(67, 74, 'DRG'), (14, 26, 'ADR')]}),
#  ('so so so shaky me and effexor xr have a love/hate relationship effexor',
#   {'entities': [(63, 70, 'DRG'), (9, 14, 'ADR')]}),
#  ('i have to wake up every morning at 7 30am and take my effexor',
#   {'entities': []}),
#  ("i just typed 'except' and my phone suggested 'effexor ' maybe it knows something i don't",
#   {'entities': []}),
#  ('second day off effexor & on viibryd here brain zaps are fun and by fun i mean horrendous & miserable effexor',
#   {'entities': [(101, 108, 'DRG'), (41, 51, 'ADR')]}),
#  ("i'll go untreated for 8 weeks that is extremely scary if i wasn't on effexor and ativan i would be having panic attacks thank god no pain effexor",
#   {'entities': [(138, 145, 'DRG')]}),
#  ('day 6 cold turkey from effexor i bellevue this pic adequately represents my descent into madness or whatever effexor',
#   {'entities': [(109, 116, 'DRG'), (76, 96, 'ADR')]}),
#  ("headache & stomach ache i'm never forgetting my effexor again effexor",
#   {'entities': [(62, 69, 'DRG'), (0, 8, 'ADR')]}),
#  ("headache & stomach ache i'm never forgetting my effexor again effexor",
#   {'entities': [(62, 69, 'DRG'), (11, 23, 'ADR')]}),
#  ('rt the mental illness circle is not without it\'s elitists "i\'m on effexor " "pfft amateur "',
#   {'entities': []}),
#  ('oh i hate that i used to be on citalopram it stopped working eventually sometimes i have to up my effexor dose temporarily effexor',
#   {'entities': [(123, 130, 'DRG'), (45, 60, 'ADR')]}),
#  ('out of pills feeling like a train wreck tweaking effexor effexor',
#   {'entities': [(57, 64, 'DRG'), (40, 48, 'ADR')]}),
#  ('out of pills feeling like a train wreck tweaking effexor effexor',
#   {'entities': [(57, 64, 'DRG'), (13, 39, 'ADR')]}),
#  ('wellbutrin did a pretty good job canceling out the side effects of effexor back when i was on both',
#   {'entities': []}),
#  ('realtalk until i started taking wellbutrin effexor robbed me of the ability to cum effexor',
#   {'entities': [(83, 90, 'DRG'), (68, 82, 'ADR')]}),
#  ('effexor xr side effects sucidal thoughts insomnia feeling high & unresponsible dry mouth effexor',
#   {'entities': [(89, 96, 'DRG'), (79, 88, 'ADR')]}),
#  ('effexor xr side effects sucidal thoughts insomnia feeling high & unresponsible dry mouth effexor',
#   {'entities': [(89, 96, 'DRG'), (50, 62, 'ADR')]}),
#  ('effexor xr side effects sucidal thoughts insomnia feeling high & unresponsible dry mouth effexor',
#   {'entities': [(89, 96, 'DRG'), (41, 49, 'ADR')]}),
#  ('effexor xr side effects sucidal thoughts insomnia feeling high & unresponsible dry mouth effexor',
#   {'entities': [(89, 96, 'DRG'), (65, 78, 'ADR')]}),
#  ('effexor xr side effects sucidal thoughts insomnia feeling high & unresponsible dry mouth effexor',
#   {'entities': [(89, 96, 'DRG'), (24, 40, 'ADR')]}),
#  ("i've no probs with porn other than the fact that i've gained 80 pounds on effexor and no one needs to see that ) effexor",
#   {'entities': [(113, 120, 'DRG'), (54, 70, 'ADR')]}),
#  ('i had those really bad when i quit taking effexor', {'entities': []}),
#  ('the effexor dreams have taken a terrifying turn ugh effexor',
#   {'entities': [(52, 59, 'DRG'), (12, 18, 'ADR')]}),
#  ("ugh sorry this effexor is not making me feel so awesome posting puck's stuff tonight though effexor",
#   {'entities': [(92, 99, 'DRG'), (26, 55, 'ADR')]}),
#  ('struggling with effexor withdrawal worse than any symptoms i was taking the drug for stay away from this effexor',
#   {'entities': [(105, 112, 'DRG'), (24, 34, 'ADR')]}),
#  ('ssri discontinuation syndrome is a bitch effexor i hate you wellbutrin thanks for being nice to me now do your job kthx depression effexor',
#   {'entities': [(131, 138, 'DRG'), (5, 29, 'ADR')]}),
#  ('are effexor xr and regular the same thing because i just got my refill and they refilled it with regular instead of my usual xr',
#   {'entities': []}),
#  ('effexor dreams d effexor', {'entities': [(17, 24, 'DRG'), (8, 14, 'ADR')]}),
#  ('you want bad withdrawl effexor had that evil stuff for me never again i strongly believe it caused some memory damage for me ( effexor',
#   {'entities': [(127, 134, 'DRG'), (104, 117, 'ADR')]}),
#  ('you want bad withdrawl effexor had that evil stuff for me never again i strongly believe it caused some memory damage for me ( effexor',
#   {'entities': [(127, 134, 'DRG'), (13, 22, 'ADR')]}),
#  ("dunno if it's alanis the scotus rulings or that i've finally stopped my effexor but i've been on the verge of joyous tears all morning",
#   {'entities': []}),
#  ("so i'm watching side effects & the old shrink is telling the new shrink what girl used to take & says effexor i'm like hey i take that lmao",
#   {'entities': []}),
#  ('life fucked mind falling into a realm of utter disillusion thank the lord for effexor contributing to it effexor',
#   {'entities': [(105, 112, 'DRG'), (17, 58, 'ADR')]}),
#  ("yeah i'm ok that was weird might've been meds got a new batch yesterday i'm remembering the effexor xr making me sick once effexor",
#   {'entities': [(123, 130, 'DRG'), (113, 117, 'ADR')]}),
#  ("i suggest never stop taking effexor abruptly because you will feel like you're on your death bed effexor",
#   {'entities': [(97, 104, 'DRG'), (62, 96, 'ADR')]}),
#  ("zoloft was just as bad as effexor it made me more depressed and more suicidal i don't want it effexor",
#   {'entities': [(94, 101, 'DRG'), (50, 59, 'ADR')]}),
#  ("zoloft was just as bad as effexor it made me more depressed and more suicidal i don't want it effexor",
#   {'entities': [(94, 101, 'DRG'), (69, 77, 'ADR')]}),
#  ("fucking effexor withdrawals i would shake my fist but i don't have the energy effexor",
#   {'entities': [(78, 85, 'DRG'), (56, 77, 'ADR')]}),
#  ("fucking effexor withdrawals i would shake my fist but i don't have the energy effexor",
#   {'entities': [(78, 85, 'DRG'), (16, 27, 'ADR')]}),
#  ("they're switching me to effexor look at me i'm the silver linings playbook and shit i feel like a star",
#   {'entities': []}),
#  ('well my effexor kinda did its job to keep my anxiety under control but now to get my heart rate down ugh effexor',
#   {'entities': [(105, 112, 'DRG'), (85, 95, 'ADR')]}),
#  ("effexor xr is the worst pill ever omg thank god i didn't take it for a long while jfc",
#   {'entities': []}),
#  ('fuck you effexor dilated pupils and blurry vision and nausea and headaches this is awful effexor',
#   {'entities': [(89, 96, 'DRG'), (36, 49, 'ADR')]}),
#  ('fuck you effexor dilated pupils and blurry vision and nausea and headaches this is awful effexor',
#   {'entities': [(89, 96, 'DRG'), (17, 31, 'ADR')]}),
#  ('fuck you effexor dilated pupils and blurry vision and nausea and headaches this is awful effexor',
#   {'entities': [(89, 96, 'DRG'), (65, 74, 'ADR')]}),
#  ('fuck you effexor dilated pupils and blurry vision and nausea and headaches this is awful effexor',
#   {'entities': [(89, 96, 'DRG'), (54, 60, 'ADR')]}),
#  ("dear alternative medicine aficionados don't do intra nasal acupuncture when you're on effient and aspirin nightmare bloodbath effient",
#   {'entities': [(126, 133, 'DRG'), (116, 125, 'ADR')]}),
#  ("rt can you say plant based computing & super effient room temp processors bbc news plants 'do maths'",
#   {'entities': []}),
#  ('rt also a physician should order loading dose of plavix effient or brilianta medstudents residents',
#   {'entities': []}),
#  ('eliquis good drug but if ttr is 70 75% no advantage over warfarin cheapcompitition',
#   {'entities': []}),
#  ("xarelto eliquis and pradaxa are all great drugs except they don't have antidotes and that's my only reason to prefer coumadin",
#   {'entities': []}),
#  ('rt pam analysis of eliquis review docs shows approval delayed by fraud dispensing errors in pivotal trial [free]',
#   {'entities': []}),
#  ...]

# %%
dataframe = pd.read_table("/content/task3_validation.tsv",usecols=usecols)
eval_data=[]
for tweet in dataframe.iterrows():
  tweet_txt = tweet[1][2].lower()
  tweet_txt = preprocess_tweet(tweet_txt)
  data = []
  entities = []

  if not pd.isnull(tweet[1][1]):
    drug = preprocess_tweet(tweet[1][1])
    start = len(tweet_txt)+1
    
    tweet_txt = tweet_txt + " "+ drug
    end = len(tweet_txt)
    entities.append((start, end, "DRG"))

  data.append(tweet_txt)

  if not pd.isnull(tweet[1][0]):
    extra_txt_s =   preprocess_tweet(tweet[1][0])
    start=tweet_txt.find(extra_txt_s)
    end = start+len(extra_txt_s)
    extra_txt_s = extra_txt_s.split()
    entities.append((start, end, "ADR"))
  
  adr_data = {"entities": entities}
  data.append(adr_data)
  eval_data.append(tuple(data))

# %%
from __future__ import unicode_literals, print_function

import plac
import random
from pathlib import Path
import spacy
from spacy.util import minibatch, compounding
from spacy.gold import GoldParse
from spacy.scorer import Scorer

# %%
test_score = 0
def evaluate(ner_model, examples):

    scorer = Scorer()
    for input_, annot in examples:
        doc_gold_text = ner_model.make_doc(input_)
        gold = GoldParse(doc_gold_text, entities=annot.get('entities'))
        pred_value = ner_model(input_)
        scorer.score(pred_value, gold)
        test_score = scorer.scores
    return scorer.scores

# %%
def main(train_data,model=None, output_dir=None, n_iter=5):
    """Load the model, set up the pipeline and train the entity recognizer."""
    if model is not None:
        nlp = spacy.load(model)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank("en")  # create blank Language class
        print("Created blank 'en' model")

    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner, last=True)
    # otherwise, get it so we can add labels
    else:
        ner = nlp.get_pipe("ner")

    # # add labels
    # for _, annotations in TRAIN_DATA:
    #     for ent in annotations.get("entities"):
    ner.add_label("ADR")
    ner.add_label("DRG")
    # get names of other pipes to disable them during training
    pipe_exceptions = ["pos","ner", "trf_wordpiecer", "trf_tok2vec"]
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
    with nlp.disable_pipes(*other_pipes):  # only train NER
        # reset and initialize the weights randomly – but only if we're
        # training a new model
        # if model is None:
        #     nlp.begin_training()
        optimizer = nlp.begin_training()
        for itn in range(n_iter):
            random.shuffle(train_data)
            losses = {}
            # batch up the examples using spaCy's minibatch
            # for data in train_data:
            #   if len(data) == 2:
            #     nlp.update(
            #         [data[0]],  # batch of texts
            #         [data[1]],  # batch of annotations
            #         drop=0.2,  # dropout - make it harder to memorise data
            #         sgd=optimizer,  # callable to update weights
                    # losses=losses)
            for data in train_data:
              if len(data) == 2:
                nlp.update(
                    [data[0]],  # batch of texts
                    [data[1]],  # batch of annotations
                    drop=0.2,  # dropout - make it harder to memorise data
                    sgd=optimizer,  # callable to update weights
                    losses=losses)
              
            print(evaluate(nlp,eval_data))
              # else:
              #   nlp.update(
              #       [data[0]],  # batch of texts
              #       # [data[1]],  # batch of annotations
              #       drop=0.2,  # dropout - make it harder to memorise data
              #       sgd=optimizer,  # callable to update weights
              #       losses=losses)
            print("Losses", losses)
        if output_dir is not None:
            output_dir = Path(output_dir)
            if not output_dir.exists():
                output_dir.mkdir()
            nlp.meta["name"] = "NER_Model"  # rename model
            nlp.to_disk(output_dir)
            print("Saved model to", output_dir)

    # test the trained model
    for text, _ in train_data:
        doc = nlp(text)
        # print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
        # print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])
    return nlp

    # # save model to output directory
    # if output_dir is not None:
    #     output_dir = Path(output_dir)
    #     if not output_dir.exists():
    #         output_dir.mkdir()
    #     nlp.to_disk(output_dir)
    #     print("Saved model to", output_dir)

    #     # test the saved model
    #     print("Loading from", output_dir)
    #     nlp2 = spacy.load(output_dir)
        # for text, _ in TRAIN_DATA:
    #         doc = nlp2(text)
    #         print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
    #         print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])

# %%
nlp = main(train_data=train_data,model='en_core_web_sm',output_dir="/content/",n_iter=5)
# Out:
# Loaded model 'en_core_web_sm'
# {'uas': 0.0, 'las': 0.0, 'las_per_type': {'': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'ents_p': 94.54545454545455, 'ents_r': 48.663101604278076, 'ents_f': 64.25419240953221, 'ents_per_type': {'ADR': {'p': 50.0, 'r': 1.392757660167131, 'f': 2.7100271002710024}, 'DRG': {'p': 95.73333333333333, 'r': 92.2879177377892, 'f': 93.97905759162303}}, 'tags_acc': 0.0, 'token_acc': 100.0, 'textcat_score': 0.0, 'textcats_per_cat': {}}
# Losses {'ner': 16539.71743432327}
# {'uas': 0.0, 'las': 0.0, 'las_per_type': {'': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'ents_p': 95.58441558441558, 'ents_r': 49.19786096256685, 'ents_f': 64.9602824360106, 'ents_per_type': {'ADR': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'DRG': {'p': 95.58441558441558, 'r': 94.60154241645245, 'f': 95.0904392764858}}, 'tags_acc': 0.0, 'token_acc': 100.0, 'textcat_score': 0.0, 'textcats_per_cat': {}}
# Losses {'ner': 16083.590673513954}
# {'uas': 0.0, 'las': 0.0, 'las_per_type': {'': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'ents_p': 93.22033898305084, 'ents_r': 51.470588235294116, 'ents_f': 66.32213608957794, 'ents_per_type': {'ADR': {'p': 58.620689655172406, 'r': 4.735376044568245, 'f': 8.762886597938145}, 'DRG': {'p': 95.83333333333334, 'r': 94.60154241645245, 'f': 95.21345407503233}}, 'tags_acc': 0.0, 'token_acc': 100.0, 'textcat_score': 0.0, 'textcats_per_cat': {}}
# Losses {'ner': 16237.111369477965}
# {'uas': 0.0, 'las': 0.0, 'las_per_type': {'': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'ents_p': 83.52402745995423, 'ents_r': 48.79679144385027, 'ents_f': 61.60337552742617, 'ents_per_type': {'ADR': {'p': 31.521739130434785, 'r': 8.07799442896936, 'f': 12.86031042128603}, 'DRG': {'p': 97.3913043478261, 'r': 86.37532133676092, 'f': 91.55313351498637}}, 'tags_acc': 0.0, 'token_acc': 100.0, 'textcat_score': 0.0, 'textcats_per_cat': {}}
# Losses {'ner': 15840.481017126529}
# {'uas': 0.0, 'las': 0.0, 'las_per_type': {'': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'ents_p': 80.6083650190114, 'ents_r': 56.68449197860963, 'ents_f': 66.56200941915228, 'ents_per_type': {'ADR': {'p': 37.410071942446045, 'r': 14.484679665738161, 'f': 20.883534136546185}, 'DRG': {'p': 96.12403100775194, 'r': 95.62982005141389, 'f': 95.87628865979381}}, 'tags_acc': 0.0, 'token_acc': 100.0, 'textcat_score': 0.0, 'textcats_per_cat': {}}
# Losses {'ner': 16080.479472842137}
# Saved model to /content

# %%
i=0
for tweet in dataframe.iterrows():
  tweet_txt = tweet[1][1].lower()
  tweet_txt = preprocess_tweet(tweet_txt)
  print(tweet_txt)
  doc = nlp(tweet_txt)
  print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
  print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])

  
  print("-"*200)
      
  if i>5:
    break
  i = i+1
# Out:
# avelox
# Entities []
# Tokens [('avelox', '', 2)]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# avelox
# Entities []
# Tokens [('avelox', '', 2)]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# baclofen
# Entities []
# Tokens [('baclofen', '', 2)]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# baclofen
# Entities []
# Tokens [('baclofen', '', 2)]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# cipro
# Entities []
# Tokens [('cipro', '', 2)]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# cipro
# Entities []
# Tokens [('cipro', '', 2)]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# cipro
# Entities []
# Tokens [('cipro', '', 2)]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
